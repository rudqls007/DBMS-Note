# %% [markdown]
# <a href="https://colab.research.google.com/github/rudqls007/DBMS-Note/blob/master/1_DataFrame.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd # 판다스는 pandas 라이브러리를 임포트해야 사용이 가능하다. 보통 pd라는 약자(별칭) 사용

# %%
pd.DataFrame()
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
df = pd.DataFrame()
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %% [markdown]
# - DataFrame은 2차원 테이블이고, 테이블의 한 줄(행 / 열)을 Series라고 한다.
# - Series의 모임이 곧, DataFrame이 된다.

# %%
from numpy import NaN
# Series는 
pd.Series([1, 3, 5, NaN, 6, 8 ])
# Out:
# 0    1.0
# 1    3.0
# 2    5.0
# 3    NaN
# 4    6.0
# 5    8.0
# dtype: float64

# %%
stu_list = [['Michael', 'John', 'Jennie', 'Susan'], [19, 18, 17, 16]]
print(stu_list)
# Out:
# [['Michael', 'John', 'Jennie', 'Susan'], [19, 18, 17, 16]]

# %%
print(type(stu_list))
# Out:
# <class 'list'>

# %%
df = pd.DataFrame(stu_list)
df
# Out:
#          0     1       2      3
# 0  Michael  John  Jennie  Susan
# 1       19    18      17     16

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
# 데이터프레임의 로우와 컬럼을 바꾼다.
df.T
# Out:
#          0   1
# 0  Michael  19
# 1     John  18
# 2   Jennie  17
# 3    Susan  16

# %%
df
# Out:
#          0     1       2      3
# 0  Michael  John  Jennie  Susan
# 1       19    18      17     16

# %%
df = df.T
df
# Out:
#          0   1
# 0  Michael  19
# 1     John  18
# 2   Jennie  17
# 3    Susan  16

# %%
df
# Out:
#          0   1
# 0  Michael  19
# 1     John  18
# 2   Jennie  17
# 3    Susan  16

# %%
colums_name= ['name', 'age']
df.columns = colums_name
df.columns
# Out:
# Index(['name', 'age'], dtype='object')

# %%
df
# Out:
#       name age
# 0  Michael  19
# 1     John  18
# 2   Jennie  17
# 3    Susan  16
